# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px   #interactive plots and visualizations
import plotly.io as pio  #Plotly I/O for exporting and displaying  static images 
pio.renderers.default = "svg"  # Scalable Vector Graphics high-quality graphics

# %%
dataset=pd.read_csv('Zomato Chennai Listing 2020.csv')

# %%
dataset.head(70)
# Out:
#                                            Zomato URL  \
# 0   https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1   https://www.zomato.com/chennai/sukkubhai-biriy...
# 2   https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3         https://www.zomato.com/chennai/kfc-perambur
# 4   https://www.zomato.com/chennai/tasty-kitchen-p...
# ..                                                ...
# 65  https://www.zomato.com/chennai/sree-akshayam-a...
# 66  https://www.zomato.com/chennai/biriyani-palace...
# 67  https://www.zomato.com/chennai/pumpkin-tales-a...
# 68  https://www.zomato.com/chennai/sandys-chocolat...
# 69  https://www.zomato.com/chennai/hotel-saravana-...
#
#               Name of Restaurant  \
# 0          Yaa Mohaideen Briyani
# 1             Sukkubhai Biriyani
# 2           SS Hyderabad Biryani
# 3                            KFC
# 4                  Tasty Kitchen
# ..                           ...
# 65                 Sree Akshayam
# 66               Biriyani Palace
# ...

# %%
dataset.shape
# Out:
# (12032, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Zomato URL             12032 non-null  object
#  1   Name of Restaurant     12032 non-null  object
#  2   Address                12032 non-null  object
#  3   Location               12032 non-null  object
#  4   Cuisine                12032 non-null  object
#  5   Top Dishes             12032 non-null  object
#  6   Price for 2            12032 non-null  float64
#  7   Dining Rating          6681 non-null   float64
#  8   Dining Rating Count    11812 non-null  object
#  9   Delivery Rating        6181 non-null   float64
#  10  Delivery Rating Count  11812 non-null  object
#  11  Features               12032 non-null  object
# dtypes: float64(3), object(9)
# memory usage: 1.1+ MB

# %%
dataset.describe()
# Out:
#         Price for 2  Dining Rating  Delivery Rating
# count  12032.000000    6681.000000      6181.000000
# mean     397.611370       3.387756         3.805290
# std      332.045938       0.558181         0.374213
# min       40.000000       0.300000         0.300000
# 25%      200.000000       3.100000         3.600000
# 50%      300.000000       3.500000         3.900000
# 75%      450.000000       3.800000         4.000000
# max     5000.000000       4.900000         4.700000

# %%
dataset.isna().sum()
# Out:
# Zomato URL                  0
# Name of Restaurant          0
# Address                     0
# Location                    0
# Cuisine                     0
# Top Dishes                  0
# Price for 2                 0
# Dining Rating            5351
# Dining Rating Count       220
# Delivery Rating          5851
# Delivery Rating Count     220
# Features                    0
# dtype: int64

# %%
#Replacing the other null records with NA
dataset.fillna('0', inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20264\3874851706.py:2: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.

# %%
# Confirming all the null records are correct
dataset.isnull().sum()
# Out:
# Zomato URL               0
# Name of Restaurant       0
# Address                  0
# Location                 0
# Cuisine                  0
# Top Dishes               0
# Price for 2              0
# Dining Rating            0
# Dining Rating Count      0
# Delivery Rating          0
# Delivery Rating Count    0
# Features                 0
# dtype: int64

# %%
dataset.dtypes
# Out:
# Zomato URL                object
# Name of Restaurant        object
# Address                   object
# Location                  object
# Cuisine                   object
# Top Dishes                object
# Price for 2              float64
# Dining Rating             object
# Dining Rating Count       object
# Delivery Rating           object
# Delivery Rating Count     object
# Features                  object
# dtype: object

# %%
# Checking for text values in the column before converting it to numeric datatype
dataset['Dining Rating Count'].value_counts()
# Out:
# Dining Rating Count
# Does not offer Dining        2603
# Not enough Dining Reviews    2528
# 4                             339
# 5                             271
# 6                             248
#                              ...
# 877                             1
# 897                             1
# 872                             1
# 1197                            1
# 224                             1
# Name: count, Length: 793, dtype: int64

# %%
# Replacing the text values with '0'
dataset['Dining Rating Count'].replace(to_replace=['Does not offer Dining','Not enough Dining Reviews'], value='0', inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20264\3524512671.py:2: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
dataset['Delivery Rating Count'].value_counts()
# Out:
# Delivery Rating Count
# Not enough Delivery Reviews    3379
# Does not offer Delivery        2252
# 0                               239
# 27                               34
# 40                               30
#                                ...
# 7705                              1
# 6374                              1
# 3677                              1
# 588                               1
# 1617                              1
# Name: count, Length: 2281, dtype: int64

# %%
dataset['Delivery Rating Count'].replace(to_replace=['Not enough Delivery Reviews','Does not offer Delivery'], value='0', inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_20264\2781772949.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
# Changing Data Type of the numerical columns
dataset['Dining Rating'] = dataset['Dining Rating'].astype('float64')
dataset['Dining Rating Count'] = dataset['Dining Rating Count'].astype('int64')
dataset['Delivery Rating'] = dataset['Delivery Rating'].astype('float64')
dataset['Delivery Rating Count'] = dataset['Delivery Rating Count'].astype('int64')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12032 entries, 0 to 12031
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Zomato URL             12032 non-null  object
#  1   Name of Restaurant     12032 non-null  object
#  2   Address                12032 non-null  object
#  3   Location               12032 non-null  object
#  4   Cuisine                12032 non-null  object
#  5   Top Dishes             12032 non-null  object
#  6   Price for 2            12032 non-null  float64
#  7   Dining Rating          12032 non-null  float64
#  8   Dining Rating Count    12032 non-null  int64
#  9   Delivery Rating        12032 non-null  float64
#  10  Delivery Rating Count  12032 non-null  int64
#  11  Features               12032 non-null  object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 1.1+ MB

# %%
dataset.dtypes
# Out:
# Zomato URL                object
# Name of Restaurant        object
# Address                   object
# Location                  object
# Cuisine                   object
# Top Dishes                object
# Price for 2              float64
# Dining Rating            float64
# Dining Rating Count        int64
# Delivery Rating          float64
# Delivery Rating Count      int64
# Features                  object
# dtype: object

# %%
dataset.head(50)
# Out:
#                                            Zomato URL  \
# 0   https://www.zomato.com/chennai/yaa-mohaideen-b...
# 1   https://www.zomato.com/chennai/sukkubhai-biriy...
# 2   https://www.zomato.com/chennai/ss-hyderabad-bi...
# 3         https://www.zomato.com/chennai/kfc-perambur
# 4   https://www.zomato.com/chennai/tasty-kitchen-p...
# 5   https://www.zomato.com/chennai/dine-n-fun-meda...
# 6   https://www.zomato.com/chennai/bai-veetu-kalya...
# 7   https://www.zomato.com/chennai/cafe-arabica-an...
# 8   https://www.zomato.com/chennai/savoury-sea-she...
# 9   https://www.zomato.com/chennai/sangeetha-veg-r...
# 10  https://www.zomato.com/chennai/mcdonalds-velac...
# 11  https://www.zomato.com/chennai/kovai-alankar-v...
# 12  https://www.zomato.com/chennai/hotel-al-buhari...
# 13  https://www.zomato.com/chennai/dindigul-thalap...
# 14  https://www.zomato.com/chennai/hotel-paramount...
# 15  https://www.zomato.com/chennai/welcome-hotel-p...
# ...

# %%
dataset.drop('Zomato URL', axis=1, inplace=True)

# %%
dataset
# Out:
#           Name of Restaurant  \
# 0      Yaa Mohaideen Briyani
# 1         Sukkubhai Biriyani
# 2       SS Hyderabad Biryani
# 3                        KFC
# 4              Tasty Kitchen
# ...                      ...
# 12027        CK's Sandwiches
# 12028        CK's Sandwiches
# 12029        CK's Sandwiches
# 12030        CK's Sandwiches
# 12031        CK's Sandwiches
#
#                                                  Address         Location  \
# 0              336 & 338, Main Road, Pallavaram, Chennai       Pallavaram
# 1       New 14, Old 11/3Q, Railway Station Road, MKN ...          Alandur
# 2       98/339, Arcot Road, Opposite Gokulam Chit Fun...      Kodambakkam
# 3       10, Periyar Nagar, 70 Feet Road, Near Sheeba ...         Perambur
# 4       135B, SRP Colony, Peravallur, Near Perambur, ...         Perambur
# ...                                                  ...              ...
# 12027                                      Delivery Only            Porur
# ...

# %%
dataset = dataset.drop_duplicates()

# %%
zomato_chndataset = dataset.copy()

# %%
zomato_chndataset.head(50)
# Out:
#            Name of Restaurant  \
# 0       Yaa Mohaideen Briyani
# 1          Sukkubhai Biriyani
# 2        SS Hyderabad Biryani
# 3                         KFC
# 4               Tasty Kitchen
# 5                  Dine N Fun
# 6          Bai Veetu Kalyanam
# 7                Cafe Arabica
# 8           Savoury Sea Shell
# 9    Sangeetha Veg Restaurant
# 10                 McDonald's
# 11        Kovai Alankar Vilas
# 12            Hotel Al Buhari
# 13     Dindigul Thalappakatti
# 14            Hotel Paramount
# 15              Welcome Hotel
# 16                Arab Street
# 17                     Abid's
# 18    Wire Room Bar & Kitchen
# 19    Malabar Biriyani Center
# 20                    Velidis
# 21          Mami Tiffen Stall
# 22  Supriya Andhra Restaurant
# 23                    BFF 2.0
# 24             Eating Circles
# 25  Salem RR Briyani Unavagam
# 26         V4 Midnight Dhabba
# 27       Bakya Veg Restaurant
# 28           Midnight Madness
# 29             Hotel Crescent
# ...

# %% [markdown]
# ##Q1) How many restaurants are in chennai for each type of cuisine?

# %%
import plotly.offline

fig = px.histogram(zomato_chndataset, x='Cuisine', color='Cuisine',
 title= 'No. of Restaurants by cuisine',
 labels={'Cuisine':'CUISINE'})
plotly.offline.plot(fig, filename='plot.html', auto_open=True)
# Out:
# 'plot.html'

# %% [markdown]
# ##Q2) Which are the Top 10 highest rated Seafood Restaurant in chennai?

# %%
seafood_df = zomato_chndataset[zomato_chndataset['Cuisine'].str.contains('Seafood')]
seafood_df.sort_values(by='Delivery Rating',ascending=False).head(10)
# Out:
#                 Name of Restaurant  \
# 473                        Dynasty
# 2910     Taj Thalapakattu Biriyani
# 622                     Hotel Runs
# 376                     China Town
# 96                   Urban Spatula
# 903   Chidambaram New Moorthy Cafe
# 195                     The Marina
# 1398                     Nite Bite
# 14                 Hotel Paramount
# 252                Pandia's Avenue
#
#                                                 Address  \
# 473    315, Harrisons Hotel, Valluvar Kottam High Ro...
# 2910   224, Trunk Road, Opposite, Panayathamman Koil...
# 622           104/13, Sardar Patel Road, Adyar, Chennai
# 376    74, 3rd Floor, Cathedral Road, Gopalapuram, C...
# 96     Plot 1633, 54, H-Block, Ground Floor, 13th Ma...
# 903    1204, 6th Avenue, P Block, Anna Nagar West, C...
# 195             39, College Road, Nungambakkam, Chennai
# 1398                 386, Anna Salai, Saidapet, Chennai
# 14                   12/5, Ormes Road, Kilpauk, Chennai
# ...

# %% [markdown]
# ##Q3) Which is the best briyani in chennai?

# %%
Biryani_dataset = zomato_chndataset[zomato_chndataset['Cuisine'].str.contains('Biryani')]
Biryani_dataset.sort_values(by='Delivery Rating',ascending=False).head(3)
# Out:
#         Name of Restaurant                                            Address  \
# 1985         Arabian Plate   7/26, Sasthiri Nagar Main Road, Near Kakkan B...
# 3158      Biryani In A Box                  60/1, Halls Road, Egmore, Chennai
# 8779  SS Hyderabad Biryani   975, Ameer Complex, Near Kaladipet market, T....
#
#           Location                                            Cuisine  \
# 1985    Adambakkam                            ['Arabian', ' Biryani']
# 3158        Egmore                          ['Biryani', ' Fast Food']
# 8779  Tiruvottiyur  ['Biryani', ' North Indian', ' Chinese', ' Ara...
#
#      Top Dishes  Price for 2  Dining Rating  Dining Rating Count  \
# 1985    Invalid        300.0            3.7                   58
# 3158    Invalid        400.0            0.0                    0
# 8779    Invalid        500.0            3.9                  267
#
#       Delivery Rating  Delivery Rating Count  \
# 1985              4.7                    491
# ...

# %% [markdown]
# #####Q4) Which places have the highest rated restaurant for each Cuisine in chennai?

# %%
highest_rated_dataset = zomato_chndataset[zomato_chndataset['Delivery Rating'] >= 4.5]
highest_rated_dataset
# Out:
#                        Name of Restaurant  \
# 62     Amadora Gourmet Ice Cream & Sorbet
# 78                  Shri Rajasthani Dhaba
# 92              Fruit Shop On Greams Road
# 163      Momo Sa-Khang by Kailash Kitchen
# 164                          La Chocolate
# ...                                   ...
# 11043                         Kulfi Treat
# 11179                       Chennai Kulfi
# 11377            NIC - Natural Ice Creams
# 11379            NIC - Natural Ice Creams
# 11767                         Green Crush
#
#                                                  Address         Location  \
# 62      23, Wallace Garden, 3rd Street, Nungambakkam,...     Nungambakkam
# 78      C 40, 3rd Floor, 2nd Avenue, Opposite KFC, An...  Anna Nagar West
# 92             11, Greams Road, Thousand Lights, Chennai  Thousand Lights
# 163     2/247, Perinbavilas Complex, Opposite Chitra ...      Choolaimedu
# 164     5, Casa Major Road, Opposite Corporation Bank...           Egmore
# ...

# %%
import plotly.offline


fig = px.histogram(highest_rated_dataset, x='Location', color='Cuisine',
 title= 'No. of Best Restaurant for each by Location').update_xaxes(categoryorder="total descending")
plotly.offline.plot(fig, filename='plot.html', auto_open=True)
# Out:
# 'plot.html'

# %% [markdown]
# ##Q5) What is the Avg Price Distibution of highest rated restaurant for each Cuisine Type in Mumbai?

# %%
highest_rated_dataset = highest_rated_dataset.groupby(by=['Location', 'Top Dishes'])['Price for 2'].mean().reset_index()
highest_rated_dataset.head()
# Out:
#      Location                                         Top Dishes  Price for 2
# 0  Adambakkam                                            Invalid        250.0
# 1       Adyar  ['Chocolava Cake', ' Pizza Burger', ' Mexican ...        400.0
# 2       Adyar  ['Cupcake', ' Sandwich', ' Bagel', ' Brownie',...        250.0
# 3    Alwarpet                                            Invalid        200.0
# 4    Alwarpet  ['Brownie', ' Hot Chocolate', ' Cheesecake', '...        500.0

# %%
import plotly.offline

fig = px.scatter(highest_rated_dataset, x="Location", y="Price for 2", color="Top Dishes", symbol="Top Dishes",
 title=' Avg Price Distibution of High rated restaurant for each Top Dishes')#.update_traces(marker_size=0)
plotly.offline.plot(fig, filename='plot.html', auto_open=True)
# Out:
# 'plot.html'

# %% [markdown]
# ##Q6) Which areas have a large number of Chinese Restaurant Market?

# %%
chinese_dataset = zomato_chndataset[zomato_chndataset['Cuisine'].str.contains('Chinese')]
chinese_dataset
# Out:
#              Name of Restaurant  \
# 2          SS Hyderabad Biryani
# 4                 Tasty Kitchen
# 5                    Dine N Fun
# 8             Savoury Sea Shell
# 9      Sangeetha Veg Restaurant
# ...                         ...
# 12014               Bowl Bazaar
# 12015               Bowl Bazaar
# 12016               Bowl Bazaar
# 12017               Bowl Bazaar
# 12018               Bowl Bazaar
#
#                                                  Address         Location  \
# 2       98/339, Arcot Road, Opposite Gokulam Chit Fun...      Kodambakkam
# 4       135B, SRP Colony, Peravallur, Near Perambur, ...         Perambur
# 5       Opposite Forest Office, Tambaram Main Road, S...       Medavakkam
# 8       3, E Block, 3rd Avenue, Anna Nagar East, Chennai  Anna Nagar East
# 9              102/82, GN Chetty Road, T. Nagar, Chennai         T. Nagar
# ...                                                  ...              ...
# ...

# %%
chinese_rest_dataset = chinese_dataset.groupby(by='Location').agg({'Name of Restaurant' : 'count', 'Price for 2' : 'mean'}).rename(columns= {'Name of Restaurant' : 'COUNT OF RESTAURANTS'})
chinese_rest_dataset = chinese_rest_dataset.sort_values('COUNT OF RESTAURANTS', ascending=False).head(25)                                                                               
chinese_rest_dataset.head()
# Out:
#            COUNT OF RESTAURANTS  Price for 2
# Location
# Porur                       131   409.541985
# Ambattur                    116   374.568966
# Velachery                   102   488.235294
# Perambur                     99   413.636364
# Perungudi                    93   445.698925

# %%
# Assuming 'chinese_rest_df' is your DataFrame
import plotly.offline

chinese_rest_dataset.reset_index(inplace=True)  # Resetting the index to make 'REGION' a column
fig = px.bar(chinese_rest_dataset, x='Location', y='COUNT OF RESTAURANTS', color='Price for 2', title='No. of Chinese Restaurant by places')
plotly.offline.plot(fig, filename='plot.html', auto_open=True)
# Out:
# 'plot.html'

# %% [markdown]
# ##Q7) Is there a relation between Price and Rating by each Cuisine Type?

# %%
price_rating_dataset = zomato_chndataset.groupby(['Top Dishes', 'Dining Rating'])['Price for 2'].mean().reset_index()
price_rating_dataset
# Out:
#                                              Top Dishes  Dining Rating  \
# 0                                               Invalid            0.0
# 1                                               Invalid            0.3
# 2                                               Invalid            1.0
# 3                                               Invalid            1.7
# 4                                               Invalid            1.9
# ...                                                 ...            ...
# 2367  ['Wine', ' Sea Food', ' Gulab Jamun Cheesecake...            4.1
# 2368  ['Wood Fire Pizza', ' Fries', ' Iced Tea', ' T...            3.3
# 2369                                ['Wood Fire Pizza']            4.0
# 2370  ['Yellow Rice', ' Fish', ' Butter Chicken', ' ...            3.7
# 2371                                  ['Zinger Burger']            4.0
#
#       Price for 2
# 0      292.467583
# 1      250.000000
# 2      450.000000
# 3      275.000000
# ...

# %%
 # !pip install -U kaleido

# %%
import plotly.offline

fig = px.line(price_rating_dataset, y="Price for 2", x="Dining Rating",color='Top Dishes')
plotly.offline.plot(fig, filename='plot.html', auto_open=True)
# Out:
# 'plot.html'

# %% [markdown]
# ##Q8) Is there a relation between Region and Price?

# %%
region_price_dataset = zomato_chndataset.groupby(['Location'])['Price for 2'].mean().reset_index()
region_price_dataset
# Out:
#                                               Location  Price for 2
# 0     InterContinental Chennai Mahabalipuram Resort...  1500.000000
# 1                                        Abhiramapuram   228.571429
# 2                          Abu Sarovar Portico, Egmore  1000.000000
# 3                                           Adambakkam   291.025641
# 4                                                Adyar   443.550000
# ..                                                 ...          ...
# 263                              Vivira Mall, Navallur   500.000000
# 264                                       Washermenpet   291.735537
# 265             WelcomHotel, RK Salai (Cathedral Road)  2075.000000
# 266                                      West Mambalam   267.846154
# 267                     Zone by The Park, Pallikaranai  1633.333333
#
# [268 rows x 2 columns]

# %%
import plotly.offline

fig = px.scatter(region_price_dataset, x="Location", y="Price for 2").update_traces(marker_size=5)
plotly.offline.plot(fig, filename='plot.html', auto_open=True)
# Out:
# 'plot.html'

# %% [markdown]
# ##Q9) Find the list of Affordable Restaurants?

# %%
max_price = zomato_chndataset['Price for 2'].max()
one_fourth_price = max_price/4
one_fourth_price
# Out:
# 1250.0

# %%
# Finding list of restaurants that have price less than and equal to 1/4th of the max price i.e Finding Cheap Restauran
aff_rest_dataset = zomato_chndataset[['Name of Restaurant', 'Price for 2', 'Top Dishes', 'Location', 'Cuisine']]
aff_rest_dataset = aff_rest_dataset[aff_rest_dataset['Price for 2'] <= 1250]
aff_rest_dataset.sort_values(by='Price for 2', inplace=True)
aff_rest_dataset
# Out:
#                                  Name of Restaurant  Price for 2  \
# 4685                                       Soda Hub         40.0
# 6854                                    Planet Soda         50.0
# 7405                            Indian Coffee House         50.0
# 8355                                       Kaafemaa         50.0
# 1448                                     Mamee Soup         60.0
# ...                                             ...          ...
# 917                             Fabcafe By Fabindia       1200.0
# 828   Food Exchange - Novotel Chennai Chamiers Road       1200.0
# 165                                  Copper Chimney       1200.0
# 1084                18 Degree North - Clarion Hotel       1200.0
# 1166                            The Roof Top Lounge       1200.0
#
#                                              Top Dishes  \
# 4685                                            Invalid
# 6854                                            Invalid
# ...

# %%
# Finding the highest rated list of restaurants
highrate_rest_dataset = zomato_chndataset[['Name of Restaurant', 'Price for 2', 'Top Dishes', 'Location', 'Cuisine','Delivery Rating']]
highrate_rest_dataset = highrate_rest_dataset[highrate_rest_dataset['Delivery Rating'] >= 4.1]
highrate_rest_dataset.sort_values(by='Price for 2', inplace=True)
highrate_rest_dataset
# Out:
#                   Name of Restaurant  Price for 2  \
# 1518                  Lassi Junction        100.0
# 5678            JM Pazhamudir Cholai        100.0
# 2855                       Mo Square        100.0
# 2536                      Juice Spot        100.0
# 6039        Fruit Gallery Juice Shop        100.0
# ...                              ...          ...
# 243   Asia Kitchen by Mainland China       1800.0
# 102                   Mainland China       1800.0
# 234                            Hamsa       1800.0
# 333                           Teppan       2000.0
# 250                        Benjarong       2000.0
#
#                                              Top Dishes  \
# 1518                                            Invalid
# 5678                                            Invalid
# 2855                                            Invalid
# 2536                                            Invalid
# 6039                                            Invalid
# ...

# %% [markdown]
# ##Q10)Find the list of most Reliable Restaurants?

# %%
mean_votes = zomato_chndataset['Delivery Rating Count'].mean()
mean_votes
# Out:
# 713.7197139768854

# %%
# Finding list of restaurants that have Votes greater than and equal to Mean of Vote
mean_rest_dataset = zomato_chndataset[['Name of Restaurant', 'Price for 2', 'Top Dishes', 'Location', 'Cuisine', 'Delivery Rating Count']]
mean_rest_dataset = mean_rest_dataset[mean_rest_dataset['Delivery Rating Count'] >713]
mean_rest_dataset.sort_values(by='Delivery Rating Count', inplace=True)
mean_rest_dataset
# Out:
#                  Name of Restaurant  Price for 2  \
# 2146                      Om Snacks        150.0
# 903    Chidambaram New Moorthy Cafe        500.0
# 1955      Marhaba Family Restaurant        500.0
# 4240           Combo Biriyani House        400.0
# 11240        UBQ by Barbeque Nation        500.0
# ...                             ...          ...
# 8822       Sangeetha Veg Restaurant        500.0
# 232        Sapthagiri Tiffin Centre        150.0
# 22        Supriya Andhra Restaurant        650.0
# 251              Hotelkaar Biriyani        350.0
# 55                   Guntur Gongura        500.0
#
#                                               Top Dishes         Location  \
# 2146                                             Invalid      Kodambakkam
# 903    ['Paratha', ' Pepper Chicken', ' Lobster', ' E...  Anna Nagar West
# 1955             ['Tandoori Chicken', ' Dragon Chicken']      Kotturpuram
# 4240                                             Invalid         Tambaram
# ...

# %%
reliable_rest_dataset = pd.merge(mean_rest_dataset, highrate_rest_dataset, how='inner', on=['Name of Restaurant', 'Location'])
reliable_rest_dataset = reliable_rest_dataset[['Name of Restaurant', 'Price for 2_x', 'Top Dishes_x', 'Location', 'Cuisine_x']]
reliable_rest_dataset.rename(columns={'NAME':'Name of Restaurant', 'PRICE_x':'Price for 2', 'Top Dishes_x':'Top Dishes',
 'Location':'Location', 'Cuisine_x':'Cuisine'},inplace=True)

# %%
reliable_rest_dataset
# Out:
#                Name of Restaurant  Price for 2_x  \
# 0    Chidambaram New Moorthy Cafe          500.0
# 1            SS Hyderabad Biryani          500.0
# 2            SS Hyderabad Biryani          500.0
# 3            SS Hyderabad Biryani          500.0
# 4                Le Wrap Factorie          250.0
# ..                            ...            ...
# 601      Sangeetha Veg Restaurant          650.0
# 602          Krishna's Dosa Kadai          350.0
# 603            Sukkubhai Biriyani         1000.0
# 604      Sangeetha Veg Restaurant          800.0
# 605      Sangeetha Veg Restaurant          500.0
#
#                                             Top Dishes         Location  \
# 0    ['Paratha', ' Pepper Chicken', ' Lobster', ' E...  Anna Nagar West
# 1                                              Invalid         Ambattur
# 2                                              Invalid         Ambattur
# 3                                              Invalid         Ambattur
# ...
